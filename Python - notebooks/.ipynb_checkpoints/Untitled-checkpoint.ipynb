# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("~/Desktop/NCSA_genomics/Python - notebooks/GlucoCheck/Data/test/Training-TestFile.csv", sep=",") # pre-processed by removing entry "Low"
#data

# %%
data['Display Time'] = pd.to_datetime(data['Display Time'])
data['GlucoseValue'] = pd.to_numeric(data['GlucoseValue'])
xx = data[data['subjectId'] == "T101"]
xx.dtypes
# Out:
# Display Time    datetime64[ns]
# GlucoseValue             int64
# subjectId               object
# dtype: object

# %%
plt.figure(figsize=(16,8))
sns.set(style="white")
fig = sns.lineplot(x = xx['Display Time'], y = xx['GlucoseValue'],
             data=xx, palette="tab10", linewidth=0.8)
sns.despine()
fig.set_xticklabels(labels=xx['Display Time'], rotation=45, ha='right')
# Out:
# [Text(0, 0, '2015-11-24 00:37:00'),
#  Text(0, 0, '2015-11-24 00:42:00'),
#  Text(0, 0, '2015-11-24 00:47:00'),
#  Text(0, 0, '2015-11-24 00:52:00'),
#  Text(0, 0, '2015-11-24 00:57:00'),
#  Text(0, 0, '2015-11-24 01:02:00'),
#  Text(0, 0, '2015-11-24 01:07:00'),
#  Text(0, 0, '2015-11-24 01:12:00')]

# %%
data = pd.read_csv("/Users/snehgajiwala/Desktop/NCSA_genomics/Python - notebooks/GlucoCheck/Data/Output/ImputedValues.csv")

# %%
data['Display Time'] = pd.to_datetime(data['Display Time'])
data['GlucoseValue'] = pd.to_numeric(data['GlucoseValue'])
yy = data[data['subjectId'] == "T101"]
yy.dtypes
# Out:
# Display Time    datetime64[ns]
# GlucoseValue             int64
# subjectId               object
# dtype: object

# %%
plt.figure(figsize=(16,8))
sns.set(style="white")
fig = sns.lineplot(x = yy['Display Time'], y = yy['GlucoseValue'],
             data=yy, palette="tab10", linewidth=0.8)
sns.despine()
fig.set_xticklabels(labels=yy['Display Time'], rotation=60, ha='right')
# Out:
# [Text(0, 0, '2015-11-24 00:37:00'),
#  Text(0, 0, '2015-11-24 00:42:00'),
#  Text(0, 0, '2015-11-24 00:47:00'),
#  Text(0, 0, '2015-11-24 00:52:00'),
#  Text(0, 0, '2015-11-24 00:57:00'),
#  Text(0, 0, '2015-11-24 01:02:00'),
#  Text(0, 0, '2015-11-24 01:07:00'),
#  Text(0, 0, '2015-11-24 01:12:00')]

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.figure(figsize=(16,8))

sns.lineplot(x = xx['Display Time'], y = xx['GlucoseValue'],
             data=xx, ax=ax, color='r', label = 'Real')
sns.lineplot(x = yy['Display Time'], y = yy['GlucoseValue'],
             data=yy, ax=ax, color='b', label = 'Predicted')
labels = ax.get_xticklabels() 

ax.set_xticklabels(labels=yy['Display Time'], rotation=60, ha='right')
plt.show()

# %%
ax = sns.kdeplot(xx['GlucoseValue'])
ax = sns.kdeplot(yy['GlucoseValue'])

# %%
from GlucoCheck.glucoCheck import glucoCheckOps
# Out:
# Using TensorFlow backend.

# %%
glucoCheckObject = glucoCheckOps()
# Out:
# Object Created!

# %%
import pandas as pd
import random
import numpy as np
from tqdm.auto import tqdm
from sklearn.preprocessing import MinMaxScaler
from scipy import stats

import random
import re
from dateutil.parser import parse

import warnings  
warnings.filterwarnings('ignore')

import os

# %%
def createGap(df,start,end):
    """
    Creating a Gap
    input:
        start: seed
        end: seed + gap
    output:
        df: dataframe with index => DisplayTime value => GlucoseValues and a gap from start to end (inputs)
    """

    #df = readData()
    l = len(df.index)
    if end>l:
        end = l
        
    for i in range(start,end):
        df['GlucoseValue'][i]=0
    
    return df

# %%
data = pd.read_csv("~/Desktop/NCSA_genomics/Python - notebooks/GlucoCheck/Data/Hall/data_hall_raw.csv")
data = data[data['subjectId']=='1636-69-032']
data = data.reset_index(drop=True)
data.drop(['subjectId'], axis=1, inplace=True)
data['Display Time'] = data['Display Time'].apply(lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
# data = data.set_index(['Display Time'], drop=True)
data
# Out:
#             Display Time  GlucoseValue
# 0    2016-01-13 12:58:17           122
# 1    2016-01-13 13:03:17           123
# 2    2016-01-13 13:08:17           124
# 3    2016-01-13 13:13:17           128
# 4    2016-01-13 13:18:17           133
# ...                  ...           ...
# 1778 2016-01-19 17:12:49           101
# 1779 2016-01-19 17:17:49            98
# 1780 2016-01-19 17:22:49           101
# 1781 2016-01-19 17:27:49           106
# 1782 2016-01-19 17:32:49           107
#
# [1783 rows x 2 columns]

# %%
glucoCheckObject.train()
# Out:
# Training Model...
#
#
# Epoch 1/1
# 200017/200017 [==============================] - 559s 3ms/step - loss: 5.9872e-04
# Model trained successfully!

# %%
data_with_missing = data.copy()
data_with_missing = createGap(data_with_missing,150,250)

# %%
data_with_missing['subjectId'] = 'ID1'
data_with_missing
# Out:
#             Display Time  GlucoseValue subjectId
# 0    2016-01-13 12:58:17           122       ID1
# 1    2016-01-13 13:03:17           123       ID1
# 2    2016-01-13 13:08:17           124       ID1
# 3    2016-01-13 13:13:17           128       ID1
# 4    2016-01-13 13:18:17           133       ID1
# ...                  ...           ...       ...
# 1778 2016-01-19 17:12:49           101       ID1
# 1779 2016-01-19 17:17:49            98       ID1
# 1780 2016-01-19 17:22:49           101       ID1
# 1781 2016-01-19 17:27:49           106       ID1
# 1782 2016-01-19 17:32:49           107       ID1
#
# [1783 rows x 3 columns]

# %%
imputed_data = glucoCheckObject.impute(data_with_missing,1)

# %%
imputed_values = np.asarray(imputed_data['GlucoseValue'].tolist())
original_values = np.asarray(data['GlucoseValue'].tolist())

# %%
glucoCheckObject.index_agreement(imputed_values, original_values)
# Out:
# 0.9640459752253994

# %%
glucoCheckObject.rmse(imputed_values, original_values)
# Out:
# 5.865858898485178

# %%
glucoCheckObject.mad(imputed_values, original_values)
# Out:
# 1.1127313516545148

# %%
glucoCheckObject.mape(imputed_values, original_values)
# Out:
# 1.0909246811415696

# %%
data = pd.read_csv("~/Desktop/NCSA_genomics/Python - notebooks/GlucoCheck/Data/Hall/Hall_data.csv", sep=",") # pre-processed by removing entry "Low"

# %%
meta = pd.read_csv("~/Desktop/NCSA_genomics/Python - notebooks/GlucoCheck/Data/Hall/Hall_meta.csv", sep=",")

# %%
data
# Out:
#                Display Time  GlucoseValue    subjectId
# 0       2014-02-03 03:42:12            93  1636-69-001
# 1       2014-02-03 03:47:12            93  1636-69-001
# 2       2014-02-03 03:52:12            93  1636-69-001
# 3       2014-02-03 03:57:12            95  1636-69-001
# 4       2014-02-03 04:02:12            96  1636-69-001
# ...                     ...           ...          ...
# 103669  2017-07-11 20:21:32            70     2133-041
# 103670  2017-07-11 20:26:32            64     2133-041
# 103671  2017-07-11 20:31:32            61     2133-041
# 103672  2017-07-11 20:36:32            62     2133-041
# 103673  2017-07-11 20:41:32            66     2133-041
#
# [103674 rows x 3 columns]

# %%
from GlucoCheck.glucoCheck import glucoCheckOps
glucoCheckObject = glucoCheckOps()
# Out:
# Using TensorFlow backend.
# Object Created!
