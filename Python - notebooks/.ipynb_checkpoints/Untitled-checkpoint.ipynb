# %%
from TSForecasting.TsForecasting import TimeSeriesForecast
# Out:
# Using TensorFlow backend.

# %%
import dateparser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b16dd8b80396> in <module>
# ----> 1 import dateparser
#
# ModuleNotFoundError: No module named 'dateparser'

# %%
import dateutil.parser as dparser

# %%
dparser.parse("201612261047",fuzzy=True)
# Out:
# datetime.datetime(2016, 12, 26, 10, 47)

# %%
s = "2016:12:26:10:47"
k = ''.join(e for e in s if e.isalnum())
k
# Out:
# '201612261047'

# %%
z = dparser.parse(k,fuzzy=True)

# %%
type(z)
# Out:
# datetime.datetime

# %%
z.year
# Out:
# 2016

# %%
import pandas as pd
import numpy as np
import dateutil.parser as dparser

# %%
cgmdata = pd.read_csv("~/Desktop/NCSA_genomics/Data/CGManalyzer.csv") #use your path

# %%
length = cgmdata.shape[0]
length
# Out:
# 29189

# %%
from dateutil.parser import parse

# %%
for i in range(0,length):
    s = str(cgmdata.iloc[i]['timeStamp'])
    k = re.sub("[^0-9]", "", s)
    datetimeObj = parse(k) 
    cgmdata = cgmdata.replace(to_replace = s, value = datetimeObj)

# %%
cgmdata
# Out:
#          ID           timeStamp  glucoseValue
# 0      ID01 2016-06-25 09:14:00      6.000000
# 1      ID01 2016-06-25 09:17:00      6.000000
# 2      ID01 2016-06-25 09:20:00      6.000000
# 3      ID01 2016-06-25 09:23:00      5.981000
# 4      ID01 2016-06-25 09:26:00      5.972000
# ...     ...                 ...           ...
# 29184  ID31 2016-06-09 16:49:00      4.161802
# 29185  ID31 2016-06-09 16:52:00      4.104440
# 29186  ID31 2016-06-09 16:55:00      4.013856
# 29187  ID31 2016-06-09 16:58:00      3.895511
# 29188  ID31 2016-06-09 17:01:00      3.902727
#
# [29189 rows x 3 columns]

# %%
cgmdata.iloc[0]['timeStamp']
# Out:
# '2016:06:25:09:14'

# %%
s = str(cgmdata.iloc[0]['timeStamp'])
k = ''.join(e for e in s if e.isalnum())
z = dparser.parse(k,fuzzy=True)
x = ""+str(z.year)+"-"+str(z.month)+"-"+str(z.day)+" "+str(z.hour)+":"+str(z.minute)+":"+str(z.second)
cgmdata = cgmdata.replace(to_replace = s, value = x)

# %%
from datetime import datetime

# %%
s = "20160625091456"
k = ''.join(e for e in s if e.isalnum())
z = dparser.parse(k,fuzzy=True)
x = ""+str(z.year)+"-"+str(z.month)+"-"+str(z.day)+" "+str(z.hour)+":"+str(z.minute)+":"+str(z.second)
y = datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
print(y)
# Out:
# 2016-06-25 09:14:56

# %%
# Out:
# '2016-6-25 9:14:0'

# %%
import arrow

# %%
z = arrow.get('20160625091456', 'YYYYMMDDHHmmSS')

# %%
print(z)
# Out:
# 2016-06-25T09:14:00.560000+00:00

# %%
from dateutil.parser import parse
strDate = "2016:06:25:09:14"
datetimeObj = parse(strDate)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bc13464c5213> in <module>
#       1 from dateutil.parser import parse
#       2 strDate = "2016:06:25:09:14"
# ----> 3 datetimeObj = parse(strDate)
#
# /opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# /opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#     651         if len(res) == 0:
#
# ValueError: ('Unknown string format:', '2016:06:25:09:14')

# %%
print(datetimeObj)
# Out:
# 2016-06-25 09:14:56

# %%
import re
from dateutil.parser import parse

# %%
x = re.sub("[^0-9]", "", "2016:06:25:09:14")
datetimeObj = parse(x) 
print(datetimeObj)
# Out:
# 2016-06-25 09:14:00

# %%
data = pd.read_csv("~/Desktop/NCSA_genomics/Data/data_hall.txt", sep="\t", engine="python") #use your path
data['Display Time'] = data['Display Time'].apply(lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
data['time_gap'] = data['Display Time']- data['Display Time'].shift(1)
meta = pd.read_csv("~/Desktop/NCSA_genomics/Data/Hall_meta.csv")
data_description = pd.DataFrame()

for subjectId, df in data.groupby('subjectId'):
    subj_id = str(subjectId)
    temp = meta[meta["ID"]==subjectId]
    status = str(temp["status"].values[0])
    l_of_r = df['GlucoseValue'].count()
    maxGV = str(df['GlucoseValue'].max())
    minGV = str(df['GlucoseValue'].min())
    meanGV = round(df['GlucoseValue'].mean(),3)
    miss_val = len(df[df["time_gap"]>str("00:05:00")])
    P_miss_val = round(100*(len(df[df["time_gap"]>str("00:05:00")])/df['GlucoseValue'].count()),2)
    days = df['Display Time'].iloc[-1]-df['Display Time'].iloc[0]
    temp_df = pd.DataFrame({'Subject ID':[subj_id], 'Status':[status], 'Length of readings':[l_of_r], 'Max. Glucose Value':[maxGV], 'Mean Glucose Value':[meanGV], 'Missing Values':[miss_val], 'Percent of missing values':[P_miss_val], 'Days':[days]})
    data_description = pd.concat([temp_df,data_description],ignore_index=True)

display(data_description)
# Out:
#       Subject ID        Status  Length of readings Max. Glucose Value  \
# 0       2133-041  non-diabetic                1858                204
# 1       2133-040  non-diabetic                1792                171
# 2       2133-039      diabetic                2013                204
# 3       2133-037  non-diabetic                1785                153
# 4       2133-036  pre-diabetic                1954                214
# 5       2133-035  pre-diabetic                1830                190
# 6       2133-033  non-diabetic                1892                161
# 7       2133-032  non-diabetic                1781                147
# 8       2133-030  non-diabetic                1818                147
# 9       2133-028  non-diabetic                1850                111
# 10      2133-027  pre-diabetic                1936                155
# 11      2133-026  non-diabetic                1782                166
# 12      2133-025  non-diabetic                1865                175
# 13      2133-024  pre-diabetic                1821                180
# 14      2133-023  non-diabetic                1838                142
# 15      2133-022  non-diabetic                1814                204
# 16      2133-021  pre-diabetic                1797                236
# 17      2133-020  non-diabetic                1826                201
# 18      2133-019  pre-diabetic                1801                192
# 19      2133-018      diabetic                1775                303
# 20      2133-017  pre-diabetic                1799                182
# 21      2133-015  pre-diabetic                1835                213
# 22      2133-013  non-diabetic                1960                206
# 23      2133-012  non-diabetic                1935                148
# 24      2133-011  non-diabetic                1933                204
# 25      2133-010  non-diabetic                1832                143
# 26      2133-009  non-diabetic                1781                183
# 27      2133-008  non-diabetic                1805                137
# 28      2133-007  non-diabetic                1877                207
# 29      2133-006  non-diabetic                1777                148
# 30      2133-004      diabetic                1776                246
# 31      2133-003  non-diabetic                1805                190
# 32      2133-002  non-diabetic                1806                163
# 33      2133-001  non-diabetic                1814                186
# 34  1636-70-1010  pre-diabetic                1393                186
# 35  1636-70-1008  non-diabetic                1760                223
# 36  1636-70-1005  pre-diabetic                1846                225
# 37  1636-70-1003  non-diabetic                1895                146
# 38  1636-70-1002  non-diabetic                1794                168
# 39   1636-69-123  non-diabetic                1905                138
# 40   1636-69-114  pre-diabetic                1796                163
# 41   1636-69-111  non-diabetic                1720                135
# 42   1636-69-107  non-diabetic                1897                195
# 43   1636-69-091      diabetic                1803                163
# 44   1636-69-090  pre-diabetic                1863                195
# 45   1636-69-069  non-diabetic                1591                187
# 46   1636-69-064  non-diabetic                1584                218
# 47   1636-69-060  non-diabetic                1821                191
# 48   1636-69-048  non-diabetic                1779                144
# 49   1636-69-035  non-diabetic                2180                234
# 50   1636-69-032  pre-diabetic                1783                191
# 51   1636-69-028  non-diabetic                1543                168
# 52   1636-69-026  pre-diabetic                1796                182
#
#     Mean Glucose Value  Missing Values  Percent of missing values  \
# 0              108.560              54                       2.91
# 1               92.585              91                       5.08
# 2              103.922             244                      12.12
# 3               92.966              77                       4.31
# 4              107.529             243                      12.44
# 5              101.771             189                      10.33
# 6               92.981              85                       4.49
# 7               99.475              69                       3.87
# 8               93.200              46                       2.53
# 9               74.790              58                       3.14
# 10              91.118             104                       5.37
# 11              82.692              55                       3.09
# 12              87.064              61                       3.27
# 13              99.420              42                       2.31
# 14              87.567              77                       4.19
# 15             105.512              81                       4.47
# 16             130.040              57                       3.17
# 17              96.927              36                       1.97
# 18             106.728              87                       4.83
# 19             126.567              53                       2.99
# 20             109.596              54                       3.00
# 21             108.779             104                       5.67
# 22              96.813             128                       6.53
# 23              96.023              53                       2.74
# 24              95.197              78                       4.04
# 25              93.408              80                       4.37
# 26             109.652              44                       2.47
# 27              89.348              37                       2.05
# 28             111.021             126                       6.71
# 29              83.616              54                       3.04
# 30             126.619              40                       2.25
# 31             100.043              30                       1.66
# 32              94.558              55                       3.05
# 33              85.128              72                       3.97
# 34             119.359              57                       4.09
# 35             100.227              54                       3.07
# 36             112.846              71                       3.85
# 37              90.358             108                       5.70
# 38              99.394              54                       3.01
# 39              86.474              54                       2.83
# 40             113.125              57                       3.17
# 41              99.249              83                       4.83
# 42             112.329             112                       5.90
# 43             103.107              92                       5.10
# 44             108.750              84                       4.51
# 45             107.872             113                       7.10
# 46             116.333              91                       5.74
# 47             124.349              69                       3.79
# 48              97.013              40                       2.25
# 49             116.556             137                       6.28
# 50             108.316              29                       1.63
# 51             109.925              63                       4.08
# 52             115.156              78                       4.34
#
#                Days
# 0   8 days 02:09:26
# 1   6 days 10:44:37
# 2   9 days 01:34:20
# 3   6 days 07:39:25
# 4   8 days 15:04:26
# 5   7 days 05:49:42
# 6   7 days 07:04:31
# 7   6 days 04:34:25
# 8   6 days 18:44:36
# 9   7 days 02:04:30
# 10  8 days 02:13:55
# 11  6 days 04:39:35
# 12  6 days 18:09:38
# 13  6 days 13:09:23
# 14  7 days 10:09:25
# 15  6 days 12:34:33
# 16  6 days 07:39:27
# 17  6 days 10:04:43
# 18  9 days 04:34:17
# 19  6 days 04:39:35
# 20  6 days 10:04:23
# 21  6 days 17:34:22
# 22  8 days 07:49:13
# 23 12 days 10:14:03
# 24  9 days 05:54:03
# 25  6 days 17:29:32
# 26  6 days 04:34:44
# 27  6 days 07:34:31
# 28  7 days 23:14:19
# 29  6 days 04:29:35
# 30  6 days 04:29:28
# 31  6 days 07:04:28
# 32  6 days 10:44:31
# 33  7 days 00:59:29
# 34  5 days 02:04:34
# 35  6 days 04:34:32
# 36  8 days 03:24:24
# 37  7 days 07:39:28
# 38  6 days 07:34:30
# 39  8 days 01:34:20
# 40  6 days 06:59:31
# 41  6 days 06:24:41
# 42  7 days 10:09:27
# 43  6 days 10:09:39
# 44  6 days 23:39:38
# 45  6 days 20:39:24
# 46  5 days 16:14:32
# 47  6 days 14:59:31
# 48  6 days 04:34:29
# 49 11 days 01:04:20
# 50  6 days 04:34:32
# 51  5 days 19:59:40
# 52  7 days 01:29:34

# %%
type(data_description['Percent of missing values'][0])
# Out:
# numpy.float64

# %%
data_description['Length of readings'] = pd.to_numeric(data_description['Length of readings'])

# %%
import matplotlib.pyplot as plt
#data_description['Length of readings'] = pd.to_numeric(data_description['Length of readings'])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.set_size_inches(18.5, 10.5)
fig.suptitle('Length of the time series\' for all individuals' , fontsize=20)
plt.xlabel('Subject ID', fontsize=16)
plt.ylabel('Length of readings', fontsize=16)
plt.xticks(rotation='vertical')
ax.bar(data_description['Subject ID'].tolist(),data_description['Length of readings'].tolist())
plt.show()

# %%
days = []
for i in data_description['Days']:
    days.append(i.days)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.set_size_inches(18.5, 10.5)
fig.suptitle('Days in time series\' for all individuals' , fontsize=20)
plt.xlabel('Subject ID', fontsize=16)
plt.ylabel('Days', fontsize=16)
plt.xticks(rotation='vertical')
ax.bar(data_description['Subject ID'].tolist(),days)
plt.show()

# %%
#data_description['Percent of missing values'] = pd.to_numeric(data_description['Percent of missing values'])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.set_size_inches(18.5, 10.5)
fig.suptitle('Percent of missing values for all individuals' , fontsize=20)
plt.xlabel('Subject ID', fontsize=16)
plt.ylabel('Percent of missing values', fontsize=16)
plt.xticks(rotation='vertical')
ax.bar(data_description['Subject ID'].tolist(),data_description['Percent of missing values'].tolist())
plt.show()

# %%
#data_description['Missing Values'] = pd.to_numeric(data_description['Missing Values'])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.set_size_inches(18.5, 10.5)
fig.suptitle('Missing Values for all individuals' , fontsize=20)
plt.xlabel('Subject ID', fontsize=16)
plt.ylabel('Missing Values', fontsize=16)
plt.xticks(rotation='vertical')
ax.bar(data_description['Subject ID'].tolist(),data_description['Missing Values'].tolist())
plt.show()

# %%
#data_description['Mean Glucose Value'] = pd.to_numeric(data_description['Mean Glucose Value'])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.set_size_inches(18.5, 10.5)
fig.suptitle('Mean Glucose Value for all individuals' , fontsize=20)
plt.xlabel('Subject ID', fontsize=16)
plt.ylabel('Mean Glucose Value', fontsize=16)
plt.xticks(rotation='vertical')
ax.bar(data_description['Subject ID'].tolist(),data_description['Mean Glucose Value'].tolist())
plt.show()

# %%
def dataDescribe(self):
    data = pd.read_csv("~/Desktop/NCSA_genomics/Data/data_hall.txt", sep="\t", engine="python") #use your path
    data['Display Time'] = data['Display Time'].apply(lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
    data['time_gap'] = data['Display Time']- data['Display Time'].shift(1)
    meta = pd.read_csv("~/Desktop/NCSA_genomics/Data/Hall_meta.csv")
    data_description = pd.DataFrame()
    
    for subjectId, df in data.groupby('subjectId'):
        subj_id = str(subjectId)
        temp = meta[meta["ID"]==subjectId]
        status = str(temp["status"].values[0])
        l_of_r = df['GlucoseValue'].count()
        maxGV = str(df['GlucoseValue'].max())
        minGV = str(df['GlucoseValue'].min())
        meanGV = round(df['GlucoseValue'].mean(),3)
        miss_val = len(df[df["time_gap"]>str("00:05:00")])
        P_miss_val = round(100*(len(df[df["time_gap"]>str("00:05:00")])/df['GlucoseValue'].count()),2)
        days = df['Display Time'].iloc[-1]-df['Display Time'].iloc[0]
        temp_df = pd.DataFrame({'Subject ID':[subj_id], 'Status':[status], 'Length of readings':[l_of_r], 'Max. Glucose Value':[maxGV], 'Mean Glucose Value':[meanGV], 'Missing Values':[miss_val], 'Percent of missing values':[P_miss_val], 'Days':[days]})
        data_description = pd.concat([temp_df,data_description],ignore_index=True)
        
        display(data_description)

        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        fig.set_size_inches(18.5, 10.5)
        fig.suptitle('Length of the time series\' for all individuals' , fontsize=20)
        plt.xlabel('Subject ID', fontsize=16)
        plt.ylabel('Length of readings', fontsize=16)
        plt.xticks(rotation='vertical')
        ax.bar(data_description['Subject ID'].tolist(),data_description['Length of readings'].tolist())
        plt.show()
        
        days = []
        for i in data_description['Days']:
            days.append(i.days)

        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        fig.set_size_inches(18.5, 10.5)
        fig.suptitle('Days in time series\' for all individuals' , fontsize=20)
        plt.xlabel('Subject ID', fontsize=16)
        plt.ylabel('Days', fontsize=16)
        plt.xticks(rotation='vertical')
        ax.bar(data_description['Subject ID'].tolist(),days)
        plt.show()

        #data_description['Percent of missing values'] = pd.to_numeric(data_description['Percent of missing values'])
        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        fig.set_size_inches(18.5, 10.5)
        fig.suptitle('Percent of missing values for all individuals' , fontsize=20)
        plt.xlabel('Subject ID', fontsize=16)
        plt.ylabel('Percent of missing values', fontsize=16)
        plt.xticks(rotation='vertical')
        ax.bar(data_description['Subject ID'].tolist(),data_description['Percent of missing values'].tolist())
        plt.show()

        #data_description['Missing Values'] = pd.to_numeric(data_description['Missing Values'])
        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        fig.set_size_inches(18.5, 10.5)
        fig.suptitle('Missing Values for all individuals' , fontsize=20)
        plt.xlabel('Subject ID', fontsize=16)
        plt.ylabel('Missing Values', fontsize=16)
        plt.xticks(rotation='vertical')
        ax.bar(data_description['Subject ID'].tolist(),data_description['Missing Values'].tolist())
        plt.show()


        #data_description['Mean Glucose Value'] = pd.to_numeric(data_description['Mean Glucose Value'])
        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        fig.set_size_inches(18.5, 10.5)
        fig.suptitle('Mean Glucose Value for all individuals' , fontsize=20)
        plt.xlabel('Subject ID', fontsize=16)
        plt.ylabel('Mean Glucose Value', fontsize=16)
        plt.xticks(rotation='vertical')
        ax.bar(data_description['Subject ID'].tolist(),data_description['Mean Glucose Value'].tolist())
        plt.show()

# %%
testing_data = pd.read_csv("~/Desktop/NCSA_genomics/Data/Hall - 1.txt", sep="\t")

# %%
testing_data
# Out:
#              Timestamp  GlucoseValue
# 0     11-24-2015 00:37           123
# 1     11-24-2015 00:42           122
# 2     11-24-2015 00:47           119
# 3     11-24-2015 00:52           114
# 4     11-24-2015 00:57           111
# ...                ...           ...
# 1791   12-1-2015 01:46            86
# 1792   12-1-2015 01:51            82
# 1793   12-1-2015 01:56            82
# 1794   12-1-2015 02:01            83
# 1795   12-1-2015 02:06            84
#
# [1796 rows x 2 columns]

# %%
testing_data['Timestamp'] = testing_data['Timestamp'].apply(lambda x: pd.datetime.strptime(x, '%m-%d-%Y %H:%M'))
testing_data = testing_data.set_index(['Timestamp'], drop=True)

# %%
testing_data
# Out:
#                      GlucoseValue
# Timestamp
# 2015-11-24 00:37:00           123
# 2015-11-24 00:42:00           122
# 2015-11-24 00:47:00           119
# 2015-11-24 00:52:00           114
# 2015-11-24 00:57:00           111
# ...                           ...
# 2015-12-01 01:46:00            86
# 2015-12-01 01:51:00            82
# 2015-12-01 01:56:00            82
# 2015-12-01 02:01:00            83
# 2015-12-01 02:06:00            84
#
# [1796 rows x 1 columns]

# %%
testing_data.to_csv("~/Desktop/NCSA_genomics/Data/Hall_test.txt")

# %%
import pandas as pd

# %%
data = pd.read_csv("~/Desktop/NCSA_genomics/Data/CGManalyzer Trainer.csv")

# %%
data
# Out:
#               timeStamp  glucoseValue
# 0      2016:06:25:09:14      6.000000
# 1      2016:06:25:09:17      6.000000
# 2      2016:06:25:09:20      6.000000
# 3      2016:06:25:09:23      5.981000
# 4      2016:06:25:09:26      5.972000
# ...                 ...           ...
# 29184  2016:06:09:16:49      4.161802
# 29185  2016:06:09:16:52      4.104440
# 29186  2016:06:09:16:55      4.013856
# 29187  2016:06:09:16:58      3.895511
# 29188  2016:06:09:17:01      3.902727
#
# [29189 rows x 2 columns]

# %%
data['timeStamp'] = data['timeStamp'].apply(lambda x: pd.datetime.strptime(x, '%Y:%m:%d:%H:%M'))

# %%
data
# Out:
#                 timeStamp  glucoseValue
# 0     2016-06-25 09:14:00      6.000000
# 1     2016-06-25 09:17:00      6.000000
# 2     2016-06-25 09:20:00      6.000000
# 3     2016-06-25 09:23:00      5.981000
# 4     2016-06-25 09:26:00      5.972000
# ...                   ...           ...
# 29184 2016-06-09 16:49:00      4.161802
# 29185 2016-06-09 16:52:00      4.104440
# 29186 2016-06-09 16:55:00      4.013856
# 29187 2016-06-09 16:58:00      3.895511
# 29188 2016-06-09 17:01:00      3.902727
#
# [29189 rows x 2 columns]

# %%
data['glucoseValue'] = data['glucoseValue']*18

# %%
data
# Out:
#                 timeStamp  glucoseValue
# 0     2016-06-25 09:14:00    108.000000
# 1     2016-06-25 09:17:00    108.000000
# 2     2016-06-25 09:20:00    108.000000
# 3     2016-06-25 09:23:00    107.658000
# 4     2016-06-25 09:26:00    107.496000
# ...                   ...           ...
# 29184 2016-06-09 16:49:00     74.912441
# 29185 2016-06-09 16:52:00     73.879920
# 29186 2016-06-09 16:55:00     72.249399
# 29187 2016-06-09 16:58:00     70.119202
# 29188 2016-06-09 17:01:00     70.249086
#
# [29189 rows x 2 columns]

# %%
data.to_csv("~/Desktop/NCSA_genomics/Data/CGManalyzer Trainer.csv")
