# %%
from TSForecasting.TsForecasting import TimeSeriesForecast
import pandas as pd
pd.set_option("max_rows", None)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Reading all of the data

# %%
hall_raw = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Hall/data_hall_raw.csv')

hall_meta = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Hall/Hall_meta.csv')

cgm_appended = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/CGM/CGM_Analyzer_Appended.csv')

cgm_meta = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/CGM/CGM-meta.csv')

gluvarpro = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Gluvarpro/Gluvarpro.csv')

gluvarpro_meta = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Gluvarpro/GVP_metadata.csv')

ohio_full = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Ohio-Data/OhioFullConsolidated.csv')

ohio_meta = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Ohio-Data/Ohio_metadata.csv')

consolidated_paper = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/consolidatedDataForPaper.csv')

consolidated_pkg = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/consolidatedDataForPackage.csv')

consolidated_meta = pd.read_csv('~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/consolidatedMetadata.csv')

# %% [markdown]
# ***
# Creating an object
# ***

# %%
obj = TimeSeriesForecast()
# Out:
# Object Created!

# %% [markdown]
# ***
# A description of the HALL dataset
# ***

# %%
obj.dataDescribe(hall_raw,hall_meta)
# Out:
# Here is a glimpse of the data:
#
#          Display Time  GlucoseValue    subjectId
# 0 2014-02-03 03:42:12            93  1636-69-001
# 1 2014-02-03 03:47:12            93  1636-69-001
# 2 2014-02-03 03:52:12            93  1636-69-001
# 3 2014-02-03 03:57:12            95  1636-69-001
# 4 2014-02-03 04:02:12            96  1636-69-001
#
# Total Readings in the data:105426
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count           57.000000           57.000000           57.000000   57.000000
# mean          1849.578947          183.333333           51.192982   46.774794
# std            104.808149           34.955754           18.966548   17.501540
# min           1584.000000          111.000000            0.000000   21.235955
# 25%           1796.000000          153.000000           46.000000   35.487179
# 50%           1822.000000          183.000000           54.000000   43.051948
# ...

# %% [markdown]
# ***
# A description of the CGM Analyzer and CGM Analysis combined dataset
# ***

# %%
obj.dataDescribe(cgm_appended,cgm_meta)
# Out:
# Here is a glimpse of the data:
#
#          Display Time subjectId  GlucoseValue
# 0 2016-06-25 09:14:00      ID01       108.000
# 1 2016-06-25 09:17:00      ID01       108.000
# 2 2016-06-25 09:20:00      ID01       108.000
# 3 2016-06-25 09:23:00      ID01       107.658
# 4 2016-06-25 09:26:00      ID01       107.496
#
# Total Readings in the data:31791
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count           14.000000           14.000000           14.000000   14.000000
# mean          2270.785714          246.283571           61.954286   77.748718
# std            692.305533           93.808260           23.631486   42.317059
# min           1265.000000          163.800000           14.020000   33.992727
# 25%           1692.750000          183.442500           49.097500   50.232260
# 50%           2338.500000          208.100000           62.890000   62.651429
# ...

# %% [markdown]
# ***
# A description of the Gluvarpro dataset
# ***

# %%
obj.dataDescribe(gluvarpro,gluvarpro_meta)
# Out:
# Here is a glimpse of the data:
#
#          Display Time subjectId  GlucoseValue
# 0 2016-06-21 00:00:00     GVP01         197.0
# 1 2016-06-21 00:15:00     GVP01         208.0
# 2 2016-06-21 00:30:00     GVP01         226.0
# 3 2016-06-21 00:45:00     GVP01         241.0
# 4 2016-06-21 01:00:00     GVP01         250.0
#
# Total Readings in the data:46272
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count            2.000000            2.000000             2.00000    2.000000
# mean         23136.000000          388.000000            12.50000  154.736497
# std          31904.657967           57.982756            17.67767   49.295600
# min            576.000000          347.000000             0.00000  119.879244
# 25%          11856.000000          367.500000             6.25000  137.307871
# 50%          23136.000000          388.000000            12.50000  154.736497
# ...

# %% [markdown]
# ***
# A description of the OHIO dataset
# ***

# %%
obj.dataDescribe(ohio_full,ohio_meta)
# Out:
# Here is a glimpse of the data:
#
#          Display Time subjectId  GlucoseValue
# 0 2021-12-07 16:29:00     OD570           101
# 1 2021-12-07 16:34:00     OD570           100
# 2 2021-12-07 16:39:00     OD570           100
# 3 2021-12-07 16:44:00     OD570            99
# 4 2021-12-07 16:49:00     OD570            98
#
# Total Readings in the data:166533
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count           12.000000           12.000000           12.000000   12.000000
# mean         13877.750000          391.416667           41.583333  136.386108
# std           1058.275194           17.536758            2.937480   16.679054
# min          11444.000000          345.000000           40.000000  114.286517
# 25%          13331.750000          394.750000           40.000000  125.511687
# 50%          13673.500000          400.000000           40.000000  134.900485
# ...

# %% [markdown]
# ***
# A description of the consolidated dataset for the paper
#
# (cgmanalysis, CGManalyzer, gluvarpro, Ohio)
# ***

# %%
obj.dataDescribe(consolidated_paper,consolidated_meta)
# Out:
# Here is a glimpse of the data:
#
#          Display Time subjectId  GlucoseValue
# 0 2016-06-21 00:00:00     GVP01         197.0
# 1 2016-06-21 00:15:00     GVP01         208.0
# 2 2016-06-21 00:30:00     GVP01         226.0
# 3 2016-06-21 00:45:00     GVP01         241.0
# 4 2016-06-21 01:00:00     GVP01         250.0
#
# Total Readings in the data:212853
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count           28.000000           28.000000           28.000000   28.000000
# mean          7601.892857          317.106071           49.691429  108.196373
# std           8762.341947           98.519774           22.217624   45.395263
# min            576.000000          163.800000            0.000000   33.992727
# 25%           2181.500000          211.150000           40.000000   65.397143
# 50%           3178.500000          346.000000           42.500000  120.877433
# ...

# %% [markdown]
# ***
# A description of the consolidated dataset for the package
# (cgmanalysis, CGManalyzer, gluvarpro, Ohio, Hall)
# ***

# %%
obj.dataDescribe(consolidated_pkg,consolidated_meta)
# Out:
# Here is a glimpse of the data:
#
#          Display Time subjectId  GlucoseValue
# 0 2016-06-21 00:00:00     GVP01         197.0
# 1 2016-06-21 00:15:00     GVP01         208.0
# 2 2016-06-21 00:30:00     GVP01         226.0
# 3 2016-06-21 00:45:00     GVP01         241.0
# 4 2016-06-21 01:00:00     GVP01         250.0
#
# Total Readings in the data:316527
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count           88.000000           88.000000           88.000000   88.000000
# mean          3596.897727          225.158750           54.401818   66.413985
# std           5608.523425           88.449577           15.749254   41.071826
# min            576.000000          111.000000            0.000000   21.235955
# 25%           1778.500000          165.450000           44.750000   36.557581
# 50%           1821.000000          191.500000           52.500000   48.596693
# ...
