# %% [markdown]
# The package used below will have to be explicitly imported
#
# Package name: TSForecasting
#
# All the packages mentioned below will be installed automatically installed in case they are missing :
#  - pandas
#  - numpy
#  - matplotlib
#  - dateutil
#  - re
#
# The pandas package that is explicitly imported will be used to read the data supplied by you

# %%
from TSForecasting.TsForecasting import TimeSeriesForecast
import pandas as pd
# Out:
# Using TensorFlow backend.

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# To read the documentation of the class, just run the following code

# %%
TimeSeriesForecast?

# %% [markdown]
# Now, we create an object of the TimeSeriesForecast class
#
# This object contains the model and methods to predict the imputed values
#
# The object has a pretrained model on the data described below. The model is capable of performing imputations

# %%
obj = TimeSeriesForecast()
# Out:
# Epoch 1/1
# 212852/212852 [==============================] - 454s 2ms/step - loss: 5.6183e-04

# %% [markdown]
# ***
# ***
# The following method describes data that has been consolidaed from the CGMAnalyzer, Gluvarpro and  the Ohio datasets

# %%
obj.dataDescribe()
# Out:
# Here is a glimpse of the data:
#
#          Display Time subjectId  GlucoseValue
# 0 2016-06-21 00:00:00     GVP01         197.0
# 1 2016-06-21 00:15:00     GVP01         208.0
# 2 2016-06-21 00:30:00     GVP01         226.0
# 3 2016-06-21 00:45:00     GVP01         241.0
# 4 2016-06-21 01:00:00     GVP01         250.0
#        Length of readings  Max. Glucose Value  Min. Glucose Value  MAGE Score  \
# count           28.000000           28.000000           28.000000   28.000000
# mean          7601.892857          317.106071           49.691429  108.196373
# std           8762.341947           98.519774           22.217624   45.395263
# min            576.000000          163.800000            0.000000   33.992727
# 25%           2181.500000          211.150000           40.000000   65.397143
# 50%           3178.500000          346.000000           42.500000  120.877433
# 75%          10903.250000          400.000000           62.070000  139.814124
# max          45696.000000          508.710000           95.400000  189.593750
#
#                            Days
# count                        28
# mean    42 days 14:19:02.678571
# std    104 days 12:44:49.738624
# min             3 days 00:06:00
# 25%             5 days 12:03:00
# 50%            13 days 18:54:00
# 75%            45 days 11:30:00
# max           566 days 23:45:00
# Here is the statistical analysis of the data:
#    Subject ID        Status  Length of readings  Max. Glucose Value  \
# 0       OD596           NAN               10877              367.00
# 1       OD591           NAN               10847              397.00
# 2       OD588           NAN               12640              400.00
# 3       OD584           NAN               12150              400.00
# 4       OD575           NAN               11866              400.00
# 5       OD570           NAN               10982              377.00
# 6       OD567           NAN               10858              400.00
# 7       OD563           NAN               12124              400.00
# 8       OD559           NAN               10796              400.00
# 9       OD552           NAN                9080              345.00
# 10      OD544           NAN               10623              400.00
# 11      OD540           NAN               11947              369.00
# 12       ID33           NAN                1265              163.80
# 13       ID32           NAN                1337              202.00
# 14       ID31       HEALTHY                1443              182.19
# 15       ID30       HEALTHY                2472              187.20
# 16       ID29       HEALTHY                1728              195.64
# 17       ID23  PRE-DIABETIC                3260              326.83
# 18       ID22  PRE-DIABETIC                2111              170.39
# 11  2027-07-03 23:56:44
# 12  2019-03-07 06:48:00
# 13  2018-08-15 09:59:00
# 14  2016-06-09 17:01:00
# 15  2016-12-26 11:02:00
# 16  2016-12-23 13:03:00
# 17  2016-10-18 10:31:00
# 18  2017-01-02 17:05:00
# 19  2016-11-27 21:41:00
# 20  2016-12-04 19:44:00
# 21  2016-08-08 13:16:00
# 22  2017-01-11 23:04:00
# 23  2016-06-01 16:57:00
# 24  2016-06-01 14:35:00
# 25  2016-06-30 14:41:00
# 26  2017-11-11 23:45:00
# 27  2016-06-26 23:45:00

# %% [markdown]
# ***
# ***
# To see what a specific individual's glucose values look like, run the following line.
#
# In between the quotes, pass the Subject ID of that individual
#
# The different subject ID's can be found in the description table above
# ***

# %%
obj.plotSpecific('ID23')

# %% [markdown]
# ***
# ***
# To test the pretrained model, write the path of the testing dataset below:
# ***

# %%
testing_data = pd.read_csv("~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/test/generated_test.txt", sep=",")

# %% [markdown]
# ***
# ***
# Now, we run the imputation model on the data you supplied above
#
# The graph you see is the imputed glucose values
# ***

# %%
obj.impute(testing_data)
# Out:
# Gap detected!
# 566/566 [==============================] - 1s 932us/step
# Imputations performed!
# File saved!
# Location:/Users/snehgajiwala/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Output/ImputedValues.csv

# %% [markdown]
# =============================================================================================================

# %% [markdown]
# In case you wish to train your own model, use the following code
#
# Write the path to your file for the training and test set
#
#
#
# Be careful of the following:
# 1. Enter the path of your file
# 2. The file should have only two columns in the following order with the exact names: Timestamp, GlucoseValue
# 3. The date of the timestamp should have the entire year (all 4 digits). Make sure the data is numeric (irrespective of the delimiter)

# %%
training_data = pd.read_csv("~/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/test/Training-TestFile.csv")

# %% [markdown]
# ***
# ***
# Use the following function to train the model on the data you just supplied
# ***

# %%
obj.train(training_data)
# Out:
# Train shape:  (1795, 1, 1)
# Epoch 1/1
# 1795/1795 [==============================] - 4s 2ms/step - loss: 0.0209

# %% [markdown]
# ***
# ***
# To test the model you just trained, just run it on the training set we imported earlier:
# ***

# %%
obj.impute(testing_data)
# Out:
# Gap detected!
# 566/566 [==============================] - 1s 943us/step
# Imputations performed!
# File saved!
# Location:/Users/snehgajiwala/Desktop/NCSA_genomics/Python - notebooks/TSForecasting/Data/Output/ImputedValues.csv

# %% [markdown]
# Let's look at the various data we have used in our consolidated dataset:

# %%
obj.ohio_full
# Out:
#                Display Time subjectId  GlucoseValue
# 0       2021-12-07 16:29:00     OD570           101
# 1       2021-12-07 16:34:00     OD570           100
# 2       2021-12-07 16:39:00     OD570           100
# 3       2021-12-07 16:44:00     OD570            99
# 4       2021-12-07 16:49:00     OD570            98
# ...                     ...       ...           ...
# 166528  2025-06-07 16:49:51     OD552           238
# 166529  2025-06-07 16:54:51     OD552           233
# 166530  2025-06-07 16:59:51     OD552           229
# 166531  2025-06-07 17:04:51     OD552           224
# 166532  2025-06-07 17:09:51     OD552           215
#
# [166533 rows x 3 columns]

# %%
obj.cgm_appended
# Out:
#               Display Time subjectId  GlucoseValue
# 0      2016-06-25 09:14:00      ID01       108.000
# 1      2016-06-25 09:17:00      ID01       108.000
# 2      2016-06-25 09:20:00      ID01       108.000
# 3      2016-06-25 09:23:00      ID01       107.658
# 4      2016-06-25 09:26:00      ID01       107.496
# ...                    ...       ...           ...
# 31786  2019-03-07 05:48:00      ID33        79.200
# 31787  2019-03-07 06:03:00      ID33        82.800
# 31788  2019-03-07 06:18:00      ID33        84.600
# 31789  2019-03-07 06:33:00      ID33        82.800
# 31790  2019-03-07 06:48:00      ID33        79.200
#
# [31791 rows x 3 columns]

# %%
obj.gluvarpro
# Out:
#               Display Time subjectId  GlucoseValue
# 0      2016-06-21 00:00:00     GVP01         197.0
# 1      2016-06-21 00:15:00     GVP01         208.0
# 2      2016-06-21 00:30:00     GVP01         226.0
# 3      2016-06-21 00:45:00     GVP01         241.0
# 4      2016-06-21 01:00:00     GVP01         250.0
# ...                    ...       ...           ...
# 46267  2017-11-11 22:45:00     GVP03          86.0
# 46268  2017-11-11 23:00:00     GVP03         149.0
# 46269  2017-11-11 23:15:00     GVP03         178.0
# 46270  2017-11-11 23:30:00     GVP03         174.0
# 46271  2017-11-11 23:45:00     GVP03         174.0
#
# [46272 rows x 3 columns]

# %%
obj.consolidated_paper
# Out:
#               Display Time subjectId  GlucoseValue
# 0      2016-06-21 00:00:00     GVP01         197.0
# 1      2016-06-21 00:15:00     GVP01         208.0
# 2      2016-06-21 00:30:00     GVP01         226.0
# 3      2016-06-21 00:45:00     GVP01         241.0
# 4      2016-06-21 01:00:00     GVP01         250.0
# ...                    ...       ...           ...
# 212848 2025-06-28 23:36:00     OD584         206.0
# 212849 2025-06-28 23:41:00     OD584         208.0
# 212850 2025-06-28 23:46:00     OD584         213.0
# 212851 2025-06-28 23:51:00     OD584         224.0
# 212852 2025-06-28 23:56:00     OD584         235.0
#
# [212853 rows x 3 columns]

# %%
obj.consolidated_pkg
# Out:
#                Display Time subjectId  GlucoseValue
# 0       2016-06-21 00:00:00     GVP01         197.0
# 1       2016-06-21 00:15:00     GVP01         208.0
# 2       2016-06-21 00:30:00     GVP01         226.0
# 3       2016-06-21 00:45:00     GVP01         241.0
# 4       2016-06-21 01:00:00     GVP01         250.0
# ...                     ...       ...           ...
# 316522  2025-06-28 23:36:00     OD584         206.0
# 316523  2025-06-28 23:41:00     OD584         208.0
# 316524  2025-06-28 23:46:00     OD584         213.0
# 316525  2025-06-28 23:51:00     OD584         224.0
# 316526  2025-06-28 23:56:00     OD584         235.0
#
# [316527 rows x 3 columns]
